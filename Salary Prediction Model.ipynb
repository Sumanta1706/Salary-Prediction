# %%
# IMPORTING THE REQUIRED LIBRARIES FOR DATA PREPROCESSING 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings ('ignore')

# %% [markdown]
# # Data Preprocessig

# %% [markdown]
# * Load the data using the Pandas read function.
# * Print the dataset information
# * Print the stastics about the data using describe function
# * Visualize the correlation map to understand the correlation with the columns.
# * Check for null values, and if the data contains any, remove them.
# * Additionally, inspect for duplicate values and remove them if present.

# %%
# LOADING THE DATASET AND PRINTING THE TOP 5 ROWS
data = pd.read_csv('salary.csv')
data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
# ABOUT THE DATA
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# DESCRIBING THE SATATISTICS OF THE DATA 
data.describe().style.background_gradient(cmap = 'tab20c')
# Out:
# <style type="text/css">
# #T_58c12_row0_col0, #T_58c12_row0_col2, #T_58c12_row0_col4, #T_58c12_row0_col5, #T_58c12_row7_col1, #T_58c12_row7_col3 {
#   background-color: #d9d9d9;
#   color: #000000;
# }
# #T_58c12_row0_col1, #T_58c12_row1_col0, #T_58c12_row1_col2, #T_58c12_row1_col3, #T_58c12_row1_col4, #T_58c12_row1_col5, #T_58c12_row2_col0, #T_58c12_row2_col2, #T_58c12_row2_col4, #T_58c12_row2_col5, #T_58c12_row3_col0, #T_58c12_row3_col1, #T_58c12_row3_col2, #T_58c12_row3_col3, #T_58c12_row3_col4, #T_58c12_row3_col5, #T_58c12_row4_col0, #T_58c12_row4_col2, #T_58c12_row4_col3, #T_58c12_row4_col4, #T_58c12_row4_col5, #T_58c12_row5_col0, #T_58c12_row5_col2, #T_58c12_row5_col3, #T_58c12_row5_col4, #T_58c12_row5_col5, #T_58c12_row6_col0, #T_58c12_row6_col2, #T_58c12_row6_col3, #T_58c12_row6_col4, #T_58c12_row6_col5, #T_58c12_row7_col0, #T_58c12_row7_col2, #T_58c12_row7_col5 {
#   background-color: #3182bd;
#   color: #f1f1f1;
# }
# #T_58c12_row0_col3 {
#   background-color: #fdae6b;
#   color: #000000;
# }
# #T_58c12_row1_col1, #T_58c12_row5_col1, #T_58c12_row7_col4 {
#   background-color: #9ecae1;
#   color: #000000;
# }
# #T_58c12_row2_col1, #T_58c12_row2_col3, #T_58c12_row4_col1 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# #T_58c12_row6_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# </style>
# <table id="T_58c12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58c12_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_58c12_level0_col1" class="col_heading level0 col1" >fnlwgt</th>
#       <th id="T_58c12_level0_col2" class="col_heading level0 col2" >education-num</th>
#       <th id="T_58c12_level0_col3" class="col_heading level0 col3" >capital-gain</th>
#       <th id="T_58c12_level0_col4" class="col_heading level0 col4" >capital-loss</th>
#       <th id="T_58c12_level0_col5" class="col_heading level0 col5" >hours-per-week</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58c12_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_58c12_row0_col0" class="data row0 col0" >32561.000000</td>
#       <td id="T_58c12_row0_col1" class="data row0 col1" >32561.000000</td>
#       <td id="T_58c12_row0_col2" class="data row0 col2" >32561.000000</td>
#       <td id="T_58c12_row0_col3" class="data row0 col3" >32561.000000</td>
#       <td id="T_58c12_row0_col4" class="data row0 col4" >32561.000000</td>
#       <td id="T_58c12_row0_col5" class="data row0 col5" >32561.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58c12_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_58c12_row1_col0" class="data row1 col0" >38.581647</td>
#       <td id="T_58c12_row1_col1" class="data row1 col1" >189778.366512</td>
#       <td id="T_58c12_row1_col2" class="data row1 col2" >10.080679</td>
#       <td id="T_58c12_row1_col3" class="data row1 col3" >1077.648844</td>
#       <td id="T_58c12_row1_col4" class="data row1 col4" >87.303830</td>
#       <td id="T_58c12_row1_col5" class="data row1 col5" >40.437456</td>
#     </tr>
#     <tr>
#       <th id="T_58c12_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_58c12_row2_col0" class="data row2 col0" >13.640433</td>
#       <td id="T_58c12_row2_col1" class="data row2 col1" >105549.977697</td>
#       <td id="T_58c12_row2_col2" class="data row2 col2" >2.572720</td>
#       <td id="T_58c12_row2_col3" class="data row2 col3" >7385.292085</td>
#       <td id="T_58c12_row2_col4" class="data row2 col4" >402.960219</td>
#       <td id="T_58c12_row2_col5" class="data row2 col5" >12.347429</td>
#     </tr>
#     <tr>
#       <th id="T_58c12_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_58c12_row3_col0" class="data row3 col0" >17.000000</td>
#       <td id="T_58c12_row3_col1" class="data row3 col1" >12285.000000</td>
#       <td id="T_58c12_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_58c12_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_58c12_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_58c12_row3_col5" class="data row3 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58c12_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_58c12_row4_col0" class="data row4 col0" >28.000000</td>
#       <td id="T_58c12_row4_col1" class="data row4 col1" >117827.000000</td>
#       <td id="T_58c12_row4_col2" class="data row4 col2" >9.000000</td>
#       <td id="T_58c12_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_58c12_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_58c12_row4_col5" class="data row4 col5" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58c12_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_58c12_row5_col0" class="data row5 col0" >37.000000</td>
#       <td id="T_58c12_row5_col1" class="data row5 col1" >178356.000000</td>
#       <td id="T_58c12_row5_col2" class="data row5 col2" >10.000000</td>
#       <td id="T_58c12_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_58c12_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_58c12_row5_col5" class="data row5 col5" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58c12_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_58c12_row6_col0" class="data row6 col0" >48.000000</td>
#       <td id="T_58c12_row6_col1" class="data row6 col1" >237051.000000</td>
#       <td id="T_58c12_row6_col2" class="data row6 col2" >12.000000</td>
#       <td id="T_58c12_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_58c12_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_58c12_row6_col5" class="data row6 col5" >45.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58c12_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_58c12_row7_col0" class="data row7 col0" >90.000000</td>
#       <td id="T_58c12_row7_col1" class="data row7 col1" >1484705.000000</td>
#       <td id="T_58c12_row7_col2" class="data row7 col2" >16.000000</td>
#       <td id="T_58c12_row7_col3" class="data row7 col3" >99999.000000</td>
#       <td id="T_58c12_row7_col4" class="data row7 col4" >4356.000000</td>
#       <td id="T_58c12_row7_col5" class="data row7 col5" >99.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# CHECKING THE CORRELATION MATRIX
plt.figure(figsize = (9,3))
sns.heatmap(data.corr(), annot = True, cmap = 'magma_r', fmt = '.2f', linewidths = 1)
plt.title('Correlation Map')
plt.show()

# %% [markdown]
# # Data Cleaning

# %%
# CHECKING THE NULL VALUES IN THE DATASET
data.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
# CHECKING THE PERCENTAGE OF NULL VALUES IN THE DATASET
null_values = data.isna().sum()
total_shells=np.product(data.shape)
total_missing_values=null_values.sum()
percentage_missing_values=(total_missing_values/total_shells)*100
print(f'The data set contains {percentage_missing_values} of values')
# Out:
# The data set contains 0.0 of values

# %%
# CHECKING THE DUPLICATE VALUES IN THE DATASET
duplicate = data.duplicated().sum()
print(f'There is/are {duplicate} duplicate values in the dataset')
# Out:
# There is/are 24 duplicate values in the dataset

# %%
# REMOVING THE DUPLICATE VALUES FROM THE DATASET 
data = data.drop_duplicates()
after_removing_duplicates = data.duplicated().sum()
print (f'There is {after_removing_duplicates} duplicate values in the dataset')
# Out:
# There is 0 duplicate values in the dataset

# %% [markdown]
# # Data Exploration

# %% [markdown]
# * We use a for loop to print count plots for numerical columns to understand the most repeated values.
# * We also visualize a histogram for the number of hours employees work.
# * Additionally, we visualize the output percentages using a pie chart.
# * Furthermore, we perform data cleaning by replacing unwanted names in the dataset with "Others".
# * We create a pie chart to understand the distribution of output in numerical columns.
# * We generate a separate dataset for the USA to analyze the most demanded education and jobs.
# * We explore the education levels with the most hours worked in the USA.
# * Using a for loop, we visualize selected numerical columns in the USA dataset using bar charts.
# * Additionally, we utilize box plots with the dataset and hue values based on salary using a for loop.
# * Furthermore, we create a pivot table for better data understanding.
# * Lastly, we visualize the most demanded jobs with work hours ranging from less than 20 hours to 40 hours.

# %%
# CREATING A COUNT PLOT TO VISUALIZE SOME NUMERICAL COLUMNS IN THE DATA
numerical = ['education-num', 'capital-gain','hours-per-week']
for i in numerical:
    plt.figure(figsize = (30,9))
    sns.countplot(data = data, x = i, hue = 'salary')
    plt.title([i])
    plt.xticks(rotation = 90)
    plt.show()

# %%
plt.figure(figsize = (11,5))
sns.histplot(data = data, x = 'hours-per-week', bins = 44, kde = True)
plt.title("Distribution of the hours-per-week")
plt.xlabel('Hours')
plt.ylabel("Count of Value")
plt.show()

# %%
# GETTING THE PERCENTAGE OF GENDER IN THE DATA SET
data['sex'].value_counts().plot(kind = 'pie', explode = [0,0.1], labels = ['Male', 'Female'], colors = ['blue', 'pink'], 
                               autopct = '%1.2f%%', shadow = True)
plt.title("Gender percentage")
plt.show()

# %%
# DISTRIBUTION OF THE AGE COLUMN WITH GENDER
plt.figure(figsize = (20,6))
sns.countplot(data = data, x = 'age', hue = 'sex', palette = 'deep')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (9,4))
data['salary'].value_counts().sort_values(ascending = False).plot(kind = 'bar', color = ['#A9E2F3','#190710'])
plt.title("Visualize the Salary values in the data")
plt.xlabel("Salary")
plt.ylabel("Count of the values")
plt.show()

# %%
# THE DATA CONTAINS UNWANTED INFORMATION THAT ARE NOT REQUIRED SO WE'LL REPLACE THEM WITH "OTHERS" 
data['native-country'].value_counts()
# Out:
#  United-States                 29153
#  Mexico                          639
#  ?                               582
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Japan                            62
#  Guatemala                        62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
data['native-country'] = data['native-country'].str.replace('?','others')
data['workclass'] = data['workclass'].str.replace('?','others')
data['occupation'] = data['occupation'].str.replace('?','others')

# %%
# VISUALIZING TOP 20 COUNTRIES IN THE DATA
data['native-country'].value_counts().nlargest(20).plot(kind = 'bar', 
                                                         title = "Top 20 country in the data set", 
                                                         hatch = 'o', 
                                                         figsize = (11,6), 
                                                         color = ['#A9F5BC','#FA8258','#F781BE','#8000FF','#2ECCFA'])
plt.xlabel("Country name")
plt.ylabel("Count of values")
plt.show()

# %%
# CREATING PIE CHARTS TO UNDERSTAND THE RELATIONSHIPS, RACE, AND SEX COLUMN   
another_list = ['relationship','race','sex']
num_of_columns = len(another_list)
plt.figure(figsize = (24,8))
for i, col in enumerate(another_list):
    plt.subplot(1,num_of_columns, i+1)
    data[col].value_counts().plot(kind = 'pie', autopct = '%1.1f%%', startangle = 90)
    plt.title([col])
#plt.tight_layout()
plt.show()

# %%
# Create a pie chart to understand the percentage of the workclass and education and marital-status with output column
work_place = ['workclass','education','marital-status']
num_column = len(work_place)
plt.figure(figsize = (30,10))
for i, col in enumerate(work_place):
    plt.subplot(1, num_column, i+1)
    data[col].value_counts().plot(kind = 'pie', autopct = '%1.1f%%', startangle = 90)
    plt.title([col])
#plt.tight_layout()
plt.show()

# %%
# Apply the different condition to the data to creat a seperate data frame for united states and less then 40 hours per week
usa = data[data['native-country'] == ' United-States']
# Find the which education is most demanding in the unitedstates
usa['education'].value_counts().sort_values(ascending = False).plot(kind = 'bar', figsize = (12,10), 
                                                                    hatch = '*',
                                                                    color = ['#81F781','#FACC2E',
                                                                             '#E3CEF6','#F2F5A9','#DF0101'])
plt.title("Most Demanding eudcation in the United States")
plt.xlabel("Degree")
plt.ylabel("Count of the values")
plt.show()

# %%
# Find the total working hours with there education using the bar chart
usa.groupby('education')['hours-per-week'].sum().sort_values(ascending = False).plot(kind = 'bar',
                                                                                     figsize = (12,10),
                                                                                     hatch = '//',
                                                                                     color=['#D8F781','#0080FF',
                                                                                            '#086A87','#DA81F5','#A9F5A9'])
plt.title("Total Working hours with there degree")
plt.xlabel("Job")
plt.ylabel("Count of values")
plt.show()

# %%
#Create a countplot to understanding the informaiton about the united states
#plt.figure(figsize = (13,10))
for i in ['workclass','education','race','relationship','sex']:
    plt.figure(figsize = (13,10))
    sns.countplot(data = usa, x = i, hue = 'salary', palette = 'viridis')
    plt.title(f'information about the {i} column with salary')
    plt.xlabel([i])
    plt.ylabel("Count of the values")
    plt.xticks(rotation = 90)
    plt.show()

# %%
# Create a boxplot for numerical column with age
for i in ['workclass','education','marital-status','occupation','relationship','race']:
    plt.figure(figsize = (12,8))
    sns.boxplot(data = data, x = data[i], y = 'age', palette = 'hls')
    plt.title([i])
    plt.xlabel([i])
    plt.xticks(rotation = 90)
    plt.ylabel('Age')
    plt.show()

# %%
# Find the job between the range 20 to 40 hours with workclass
filterd_jobs = data[(data['hours-per-week']<20) & (data['hours-per-week'] <= 40)]
filterd_jobs['workclass'].value_counts().plot(kind = 'bar', figsize = (12,4), 
                                              color = ['#A9F5BC','#F78181','#FE2E9A','#0B173B','#FE9A2E'])
plt.title("Top most working jobs in the  data")
plt.xlabel("Jobs")
plt.ylabel("Count of values")
plt.show()

# %%
# using groupby condition find the some intresting facts
data.groupby('education')['salary'].value_counts().unstack().style.background_gradient(cmap = 'gist_heat_r')
# Out:
# <style type="text/css">
# #T_dbffa_row0_col0 {
#   background-color: #ffd1a3;
#   color: #000000;
# }
# #T_dbffa_row0_col1, #T_dbffa_row1_col1 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_dbffa_row1_col0 {
#   background-color: #ffc183;
#   color: #000000;
# }
# #T_dbffa_row2_col0 {
#   background-color: #ffebd7;
#   color: #000000;
# }
# #T_dbffa_row2_col1, #T_dbffa_row3_col0, #T_dbffa_row5_col1, #T_dbffa_row14_col0 {
#   background-color: #fff9f3;
#   color: #000000;
# }
# #T_dbffa_row3_col1, #T_dbffa_row13_col0 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_dbffa_row4_col0 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_dbffa_row4_col1, #T_dbffa_row10_col0 {
#   background-color: #fffdfb;
#   color: #000000;
# }
# #T_dbffa_row5_col0 {
#   background-color: #ffdfbf;
#   color: #000000;
# }
# #T_dbffa_row6_col0 {
#   background-color: #ffe7cf;
#   color: #000000;
# }
# #T_dbffa_row6_col1 {
#   background-color: #fffbf7;
#   color: #000000;
# }
# #T_dbffa_row7_col0 {
#   background-color: #ffd5ab;
#   color: #000000;
# }
# #T_dbffa_row7_col1 {
#   background-color: #ffc58b;
#   color: #000000;
# }
# #T_dbffa_row8_col0 {
#   background-color: #ffc78f;
#   color: #000000;
# }
# #T_dbffa_row8_col1 {
#   background-color: #ffad5b;
#   color: #000000;
# }
# #T_dbffa_row9_col0 {
#   background-color: #f94d00;
#   color: #f1f1f1;
# }
# #T_dbffa_row9_col1, #T_dbffa_row11_col0, #T_dbffa_row13_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_dbffa_row10_col1 {
#   background-color: #ffbb77;
#   color: #000000;
# }
# #T_dbffa_row11_col1 {
#   background-color: #5e0000;
#   color: #f1f1f1;
# }
# #T_dbffa_row12_col0 {
#   background-color: #ffd7af;
#   color: #000000;
# }
# #T_dbffa_row12_col1 {
#   background-color: #da2300;
#   color: #f1f1f1;
# }
# #T_dbffa_row14_col1 {
#   background-color: #ff9f3f;
#   color: #000000;
# }
# #T_dbffa_row15_col0 {
#   background-color: #800000;
#   color: #f1f1f1;
# }
# #T_dbffa_row15_col1 {
#   background-color: #900000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dbffa">
#   <thead>
#     <tr>
#       <th class="index_name level0" >salary</th>
#       <th id="T_dbffa_level0_col0" class="col_heading level0 col0" > <=50K</th>
#       <th id="T_dbffa_level0_col1" class="col_heading level0 col1" > >50K</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbffa_level0_row0" class="row_heading level0 row0" > 10th</th>
#       <td id="T_dbffa_row0_col0" class="data row0 col0" >871.000000</td>
#       <td id="T_dbffa_row0_col1" class="data row0 col1" >62.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row1" class="row_heading level0 row1" > 11th</th>
#       <td id="T_dbffa_row1_col0" class="data row1 col0" >1115.000000</td>
#       <td id="T_dbffa_row1_col1" class="data row1 col1" >60.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row2" class="row_heading level0 row2" > 12th</th>
#       <td id="T_dbffa_row2_col0" class="data row2 col0" >400.000000</td>
#       <td id="T_dbffa_row2_col1" class="data row2 col1" >33.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row3" class="row_heading level0 row3" > 1st-4th</th>
#       <td id="T_dbffa_row3_col0" class="data row3 col0" >160.000000</td>
#       <td id="T_dbffa_row3_col1" class="data row3 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row4" class="row_heading level0 row4" > 5th-6th</th>
#       <td id="T_dbffa_row4_col0" class="data row4 col0" >316.000000</td>
#       <td id="T_dbffa_row4_col1" class="data row4 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row5" class="row_heading level0 row5" > 7th-8th</th>
#       <td id="T_dbffa_row5_col0" class="data row5 col0" >605.000000</td>
#       <td id="T_dbffa_row5_col1" class="data row5 col1" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row6" class="row_heading level0 row6" > 9th</th>
#       <td id="T_dbffa_row6_col0" class="data row6 col0" >487.000000</td>
#       <td id="T_dbffa_row6_col1" class="data row6 col1" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row7" class="row_heading level0 row7" > Assoc-acdm</th>
#       <td id="T_dbffa_row7_col0" class="data row7 col0" >802.000000</td>
#       <td id="T_dbffa_row7_col1" class="data row7 col1" >265.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row8" class="row_heading level0 row8" > Assoc-voc</th>
#       <td id="T_dbffa_row8_col0" class="data row8 col0" >1021.000000</td>
#       <td id="T_dbffa_row8_col1" class="data row8 col1" >361.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row9" class="row_heading level0 row9" > Bachelors</th>
#       <td id="T_dbffa_row9_col0" class="data row9 col0" >3132.000000</td>
#       <td id="T_dbffa_row9_col1" class="data row9 col1" >2221.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row10" class="row_heading level0 row10" > Doctorate</th>
#       <td id="T_dbffa_row10_col0" class="data row10 col0" >107.000000</td>
#       <td id="T_dbffa_row10_col1" class="data row10 col1" >306.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row11" class="row_heading level0 row11" > HS-grad</th>
#       <td id="T_dbffa_row11_col0" class="data row11 col0" >8820.000000</td>
#       <td id="T_dbffa_row11_col1" class="data row11 col1" >1674.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row12" class="row_heading level0 row12" > Masters</th>
#       <td id="T_dbffa_row12_col0" class="data row12 col0" >763.000000</td>
#       <td id="T_dbffa_row12_col1" class="data row12 col1" >959.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row13" class="row_heading level0 row13" > Preschool</th>
#       <td id="T_dbffa_row13_col0" class="data row13 col0" >50.000000</td>
#       <td id="T_dbffa_row13_col1" class="data row13 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row14" class="row_heading level0 row14" > Prof-school</th>
#       <td id="T_dbffa_row14_col0" class="data row14 col0" >153.000000</td>
#       <td id="T_dbffa_row14_col1" class="data row14 col1" >423.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbffa_level0_row15" class="row_heading level0 row15" > Some-college</th>
#       <td id="T_dbffa_row15_col0" class="data row15 col0" >5896.000000</td>
#       <td id="T_dbffa_row15_col1" class="data row15 col1" >1386.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create a pivot table 
pivot_table = data.pivot_table(columns = 'workclass', index = 'education', values = 'hours-per-week', aggfunc =  'sum')
pivot_table.style.background_gradient(cmap = 'cividis_r')
# Out:
# <style type="text/css">
# #T_a3700_row0_col0, #T_a3700_row1_col0, #T_a3700_row10_col3, #T_a3700_row14_col8 {
#   background-color: #fce236;
#   color: #000000;
# }
# #T_a3700_row0_col1, #T_a3700_row10_col1 {
#   background-color: #f2da44;
#   color: #000000;
# }
# #T_a3700_row0_col2, #T_a3700_row9_col1, #T_a3700_row9_col4, #T_a3700_row11_col0, #T_a3700_row11_col1, #T_a3700_row11_col3, #T_a3700_row11_col5, #T_a3700_row11_col7, #T_a3700_row11_col8, #T_a3700_row15_col6 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# #T_a3700_row0_col3 {
#   background-color: #ebd44b;
#   color: #000000;
# }
# #T_a3700_row0_col4, #T_a3700_row1_col1, #T_a3700_row1_col5, #T_a3700_row5_col3 {
#   background-color: #f3db42;
#   color: #000000;
# }
# #T_a3700_row0_col5, #T_a3700_row7_col8 {
#   background-color: #efd748;
#   color: #000000;
# }
# #T_a3700_row0_col6, #T_a3700_row5_col1 {
#   background-color: #f5dc41;
#   color: #000000;
# }
# #T_a3700_row0_col7, #T_a3700_row1_col7, #T_a3700_row2_col2, #T_a3700_row2_col7, #T_a3700_row3_col0, #T_a3700_row3_col2, #T_a3700_row3_col7, #T_a3700_row4_col2, #T_a3700_row4_col7, #T_a3700_row6_col2, #T_a3700_row6_col7, #T_a3700_row7_col2, #T_a3700_row8_col2, #T_a3700_row8_col7, #T_a3700_row9_col2, #T_a3700_row9_col7, #T_a3700_row10_col2, #T_a3700_row10_col7, #T_a3700_row12_col2, #T_a3700_row12_col7, #T_a3700_row13_col0, #T_a3700_row13_col2, #T_a3700_row13_col4, #T_a3700_row13_col5, #T_a3700_row13_col7, #T_a3700_row14_col2, #T_a3700_row14_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a3700_row0_col8 {
#   background-color: #cdbb63;
#   color: #000000;
# }
# #T_a3700_row1_col2, #T_a3700_row3_col1, #T_a3700_row3_col4, #T_a3700_row3_col5, #T_a3700_row3_col6, #T_a3700_row4_col0, #T_a3700_row5_col0, #T_a3700_row5_col7, #T_a3700_row7_col7, #T_a3700_row13_col1, #T_a3700_row13_col3, #T_a3700_row13_col6, #T_a3700_row13_col8 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_a3700_row1_col3 {
#   background-color: #e6d051;
#   color: #000000;
# }
# #T_a3700_row1_col4, #T_a3700_row2_col3, #T_a3700_row2_col6, #T_a3700_row14_col3 {
#   background-color: #f8df3c;
#   color: #000000;
# }
# #T_a3700_row1_col6, #T_a3700_row5_col4, #T_a3700_row6_col3, #T_a3700_row10_col5 {
#   background-color: #f6dd3f;
#   color: #000000;
# }
# #T_a3700_row1_col8 {
#   background-color: #c5b568;
#   color: #000000;
# }
# #T_a3700_row2_col0, #T_a3700_row3_col3, #T_a3700_row3_col8 {
#   background-color: #fee434;
#   color: #000000;
# }
# #T_a3700_row2_col1, #T_a3700_row4_col3, #T_a3700_row6_col4 {
#   background-color: #f9e03a;
#   color: #000000;
# }
# #T_a3700_row2_col4, #T_a3700_row6_col6, #T_a3700_row10_col8 {
#   background-color: #fde334;
#   color: #000000;
# }
# #T_a3700_row2_col5, #T_a3700_row4_col1, #T_a3700_row4_col6 {
#   background-color: #fee535;
#   color: #000000;
# }
# #T_a3700_row2_col8, #T_a3700_row10_col0 {
#   background-color: #edd54a;
#   color: #000000;
# }
# #T_a3700_row4_col4, #T_a3700_row4_col5, #T_a3700_row6_col0 {
#   background-color: #fee636;
#   color: #000000;
# }
# #T_a3700_row4_col8 {
#   background-color: #f1d945;
#   color: #000000;
# }
# #T_a3700_row5_col2 {
#   background-color: #918b78;
#   color: #f1f1f1;
# }
# #T_a3700_row5_col5, #T_a3700_row7_col3 {
#   background-color: #e7d150;
#   color: #000000;
# }
# #T_a3700_row5_col6, #T_a3700_row6_col5 {
#   background-color: #fbe138;
#   color: #000000;
# }
# #T_a3700_row5_col8, #T_a3700_row7_col6 {
#   background-color: #dcc859;
#   color: #000000;
# }
# #T_a3700_row6_col1 {
#   background-color: #f7de3e;
#   color: #000000;
# }
# #T_a3700_row6_col8 {
#   background-color: #e8d24f;
#   color: #000000;
# }
# #T_a3700_row7_col0 {
#   background-color: #c6b667;
#   color: #000000;
# }
# #T_a3700_row7_col1 {
#   background-color: #d1bf61;
#   color: #000000;
# }
# #T_a3700_row7_col4, #T_a3700_row8_col5 {
#   background-color: #dfca57;
#   color: #000000;
# }
# #T_a3700_row7_col5 {
#   background-color: #eed649;
#   color: #000000;
# }
# #T_a3700_row8_col0 {
#   background-color: #d7c45c;
#   color: #000000;
# }
# #T_a3700_row8_col1 {
#   background-color: #d0be62;
#   color: #000000;
# }
# #T_a3700_row8_col3, #T_a3700_row12_col5 {
#   background-color: #ddc858;
#   color: #000000;
# }
# #T_a3700_row8_col4, #T_a3700_row14_col0, #T_a3700_row14_col6 {
#   background-color: #dbc75a;
#   color: #000000;
# }
# #T_a3700_row8_col6 {
#   background-color: #d2c060;
#   color: #000000;
# }
# #T_a3700_row8_col8 {
#   background-color: #e1cc55;
#   color: #000000;
# }
# #T_a3700_row9_col0 {
#   background-color: #233c6e;
#   color: #f1f1f1;
# }
# #T_a3700_row9_col3 {
#   background-color: #817f78;
#   color: #f1f1f1;
# }
# #T_a3700_row9_col5 {
#   background-color: #8b8778;
#   color: #f1f1f1;
# }
# #T_a3700_row9_col6, #T_a3700_row15_col8 {
#   background-color: #002b62;
#   color: #f1f1f1;
# }
# #T_a3700_row9_col8 {
#   background-color: #a89e73;
#   color: #f1f1f1;
# }
# #T_a3700_row10_col4 {
#   background-color: #dac65b;
#   color: #000000;
# }
# #T_a3700_row10_col6 {
#   background-color: #9c9576;
#   color: #f1f1f1;
# }
# #T_a3700_row11_col2 {
#   background-color: #7c7b78;
#   color: #f1f1f1;
# }
# #T_a3700_row11_col4, #T_a3700_row15_col0 {
#   background-color: #002859;
#   color: #f1f1f1;
# }
# #T_a3700_row11_col6 {
#   background-color: #002e6a;
#   color: #f1f1f1;
# }
# #T_a3700_row12_col0 {
#   background-color: #b7a96e;
#   color: #f1f1f1;
# }
# #T_a3700_row12_col1 {
#   background-color: #444f6c;
#   color: #f1f1f1;
# }
# #T_a3700_row12_col3 {
#   background-color: #dec958;
#   color: #000000;
# }
# #T_a3700_row12_col4 {
#   background-color: #aca172;
#   color: #f1f1f1;
# }
# #T_a3700_row12_col6 {
#   background-color: #646770;
#   color: #f1f1f1;
# }
# #T_a3700_row12_col8 {
#   background-color: #ead34c;
#   color: #000000;
# }
# #T_a3700_row14_col1 {
#   background-color: #f0d846;
#   color: #000000;
# }
# #T_a3700_row14_col4 {
#   background-color: #ada272;
#   color: #f1f1f1;
# }
# #T_a3700_row14_col5 {
#   background-color: #d9c55c;
#   color: #000000;
# }
# #T_a3700_row15_col1 {
#   background-color: #3d4a6c;
#   color: #f1f1f1;
# }
# #T_a3700_row15_col2 {
#   background-color: #6d6f72;
#   color: #f1f1f1;
# }
# #T_a3700_row15_col3 {
#   background-color: #61656f;
#   color: #f1f1f1;
# }
# #T_a3700_row15_col4 {
#   background-color: #2d416d;
#   color: #f1f1f1;
# }
# #T_a3700_row15_col5 {
#   background-color: #747475;
#   color: #f1f1f1;
# }
# #T_a3700_row15_col7 {
#   background-color: #b5a86f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a3700">
#   <thead>
#     <tr>
#       <th class="index_name level0" >workclass</th>
#       <th id="T_a3700_level0_col0" class="col_heading level0 col0" > Federal-gov</th>
#       <th id="T_a3700_level0_col1" class="col_heading level0 col1" > Local-gov</th>
#       <th id="T_a3700_level0_col2" class="col_heading level0 col2" > Never-worked</th>
#       <th id="T_a3700_level0_col3" class="col_heading level0 col3" > Private</th>
#       <th id="T_a3700_level0_col4" class="col_heading level0 col4" > Self-emp-inc</th>
#       <th id="T_a3700_level0_col5" class="col_heading level0 col5" > Self-emp-not-inc</th>
#       <th id="T_a3700_level0_col6" class="col_heading level0 col6" > State-gov</th>
#       <th id="T_a3700_level0_col7" class="col_heading level0 col7" > Without-pay</th>
#       <th id="T_a3700_level0_col8" class="col_heading level0 col8" > others</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3700_level0_row0" class="row_heading level0 row0" > 10th</th>
#       <td id="T_a3700_row0_col0" class="data row0 col0" >253.000000</td>
#       <td id="T_a3700_row0_col1" class="data row0 col1" >1185.000000</td>
#       <td id="T_a3700_row0_col2" class="data row0 col2" >70.000000</td>
#       <td id="T_a3700_row0_col3" class="data row0 col3" >25595.000000</td>
#       <td id="T_a3700_row0_col4" class="data row0 col4" >729.000000</td>
#       <td id="T_a3700_row0_col5" class="data row0 col5" >2915.000000</td>
#       <td id="T_a3700_row0_col6" class="data row0 col6" >508.000

# %%
# Some intresting questions asked from the data
print('The most demanding education is',data['education'].value_counts().idxmax())
print('\nThe least demanding  education is',data['education'].value_counts().idxmin())
print('\nThe highest working hours in the data is',data['hours-per-week'].value_counts().idxmax())
print('\nThe less working hours in the data is',data['hours-per-week'].value_counts().idxmin())
print('\nMost dominate race is',data['race'].value_counts().idxmax())
print('\nLess dominate race is ',data['race'].value_counts().idxmin())
print('\nMost dominate occupation is',data['occupation'].value_counts().idxmax())
print('\nLess dominate race is',data['occupation'].value_counts().idxmin())
# Out:
# The most demanding education is  HS-grad
#
# The least demanding  education is  Preschool
#
# The highest working hours in the data is 40
#
# The less working hours in the data is 82
#
# Most dominate race is  White
#
# Less dominate race is   Other
#
# Most dominate occupation is  Prof-specialty
#
# Less dominate race is  Armed-Forces

# %%
# Find the average working hours with occupation where more then 50 hours
long_hours_jobs = data[(data['hours-per-week'] >= 50)]
long_hours_jobs.groupby('occupation')['hours-per-week'].mean().sort_values(ascending = False)\
.plot(kind = 'bar', figsize = (12,4), color = ['#8B3A62', '#4B0082', '#00FF00', '#FCE6C9', '#00688B', '#9A32CD'])
plt.title("Average hours per week differnt occupation")
plt.xlabel("occupation")
plt.ylabel("Avergage hours per week")
plt.show()

# %%
# Find the average age of the bachelors degree holder
bachelors = data[(data['education'] == ' Bachelors')]
find_the_averge_age = bachelors.groupby('sex')['age'].mean().sort_values(ascending = False)
plt.figure(figsize = (7,4))
plt.bar(find_the_averge_age.index,find_the_averge_age.values,color = ['#FA5882','#F6CEEC'])
plt.title("Average age of the bachelors degree holders")
plt.xlabel('Gender')
plt.ylabel("Average age")
plt.show()

# %% [markdown]
# # Observation

# %% [markdown]
# * We observed that the majority of working hours per week fall within the 30 to 40 range.
# * The pie chart illustrates a higher percentage of males in the dataset.
# * The USA has the highest number of records in the dataset.
# * A significant portion of employees earned a salary of less than 50k.
# * Within the USA data, the most demanded degree is high school (hs-degree), which also corresponds to the highest working hours.
# * The pie chart provides insights into various aspects of the output.
# * Employees in the "private house service" sector work for more than 50 hours per week.
# * Working hours for employees in private companies typically range between 20 to 40 hours.

# %% [markdown]
# # Machine Learning Modelling

# %%
# Install the all Required libraries for the machine Learning Modeling
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
# Convert the all categories columns into numerical columns using the label encoding
for col in data.select_dtypes(include = 'object'):
    labelencoder = LabelEncoder()
    labelencoder.fit(data[col].unique())
    data[col] = labelencoder.transform(data[col])

# %%
# Split the data into independent and dependent variable
X = data.drop(['salary'], axis = 1)
y = data['salary']
# Normalization the data using the Standard Scaler 
standard = StandardScaler()
X = standard.fit_transform(X)
# Split the data into train and test data 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 220)

# %%
# Create a function for machine learning modeling 
def machine_learning_model(model,X_train,X_test,y_train,y_test):
    '''
    In the function we write about the code for machine learning model
    Firstly we fit the train data to the model
    and predict the values with test data and store the values with variable
    and then print the accuracy score along with classification and confusion matrix
    
    '''
    print(f'The {model} ')
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    model_score=accuracy_score(y_test,y_pred)
    print(f'\nThe accuracy score of the {model} is {model_score*100 :.2f}')
    print(f'\n {classification_report(y_test,y_pred)}')
    print(f'\n{confusion_matrix(y_test,y_pred)}')
    matrix=confusion_matrix(y_test,y_pred)
    sns.heatmap(matrix,annot=True,cmap='Reds',fmt='.2f',linewidths=1)
    plt.show()
    print('-'*30)

# %%
models={
    'logistic':LogisticRegression(penalty = 'l2'),
    'decison':DecisionTreeClassifier(criterion = 'gini', splitter = 'best'),
    'Random':RandomForestClassifier(n_estimators = 50, criterion = 'gini'),
    'Knn':KNeighborsClassifier(),
    'xgb':XGBClassifier(),
    'catboost':CatBoostClassifier(iterations = 1)
}

# %%
for i in range(len(models)):
    model_names = list(models.values())[i]
    names = list(models.keys())[i]
# And apply the machine learning function to the models
    machine_learning_model(model_names, X_train, X_test, y_train, y_test)
# Out:
# The LogisticRegression()
#
# The accuracy score of the LogisticRegression() is 82.62
#
#                precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      4941
#            1       0.73      0.45      0.55      1567
#
#     accuracy                           0.83      6508
#    macro avg       0.78      0.70      0.72      6508
# weighted avg       0.82      0.83      0.81      6508
#
#
# [[4677  264]
#  [ 867  700]]
# ------------------------------
# The DecisionTreeClassifier()
#
# The accuracy score of the DecisionTreeClassifier() is 81.24
#
#                precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88      4941
#            1       0.61      0.62      0.61      1567
#
#     accuracy                           0.81      6508
#    macro avg       0.74      0.75      0.74      6508
# weighted avg       0.81      0.81      0.81      6508
#
#
# [[4322  619]
#  [ 602  965]]
# ------------------------------
# The RandomForestClassifier(n_estimators=50)
#
# The accuracy score of the RandomForestClassifier(n_estimators=50) is 86.16
#
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      4941
#            1       0.75      0.63      0.69      1567
#
#     accuracy                           0.86      6508
#    macro avg       0.82      0.78      0.80      6508
# weighted avg       0.86      0.86      0.86      6508
#
#
# [[4620  321]
#  [ 580  987]]
# ------------------------------
# The KNeighborsClassifier()
#
# The accuracy score of the KNeighborsClassifier() is 83.37
#
#                precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      4941
#            1       0.68      0.58      0.63      1567
#
#     accuracy                           0.83      6508
#    macro avg       0.78      0.75      0.76      6508
# weighted avg       0.83      0.83      0.83      6508
#
#
# [[4520  421]
#  [ 661  906]]
# ------------------------------
# The XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
#
# The accuracy score of the XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) is 87.31
#
#                precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92      4941
#            1       0.78      0.66      0.71      1567
#
#     accuracy                           0.87      6508
#    macro avg       0.84      0.80      0.82      6508
# weighted avg       0.87      0.87      0.87      6508
#
#
# [[4647  294]
#  [ 532 1035]]
# ------------------------------
# The <catboost.core.CatBoostClassifier object at 0x00000222E4C7FBE0>
# Learning rate set to 0.5
# 0:	learn: 0.4868976	total: 143ms	remaining: 0us
#
# The accuracy score of the <catboost.core.CatBoostClassifier object at 0x00000222E4C7FBE0> is 84.53
#
#                precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      4941
#            1       0.77      0.51      0.61      1567
#
#     accuracy                           0.85      6508
#    macro avg       0.82      0.73      0.76      6508
# weighted avg       0.84      0.85      0.83      6508
#
#
# [[4706  235]
#  [ 772  795]]
# ------------------------------

# %%
Random = RandomForestClassifier()
machine_learning_model(Random, X_train, X_test, y_train, y_test)
# Out:
# The RandomForestClassifier()
#
# The accuracy score of the RandomForestClassifier() is 85.80
#
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      4941
#            1       0.74      0.63      0.68      1567
#
#     accuracy                           0.86      6508
#    macro avg       0.82      0.78      0.79      6508
# weighted avg       0.85      0.86      0.85      6508
#
#
# [[4604  337]
#  [ 587  980]]
# ------------------------------
